# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from numpy.linalg import norm
np.set_printoptions(precision = 3, suppress = True)

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-2-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
from keras import backend as K

class BiasLayer(tf.keras.layers.Layer):
    def __init__(self, *args, **kwargs):
        super(BiasLayer, self).__init__(*args, **kwargs)

    def build(self, input_shape):
        print(input_shape)
        self.bias = self.add_weight('bias',
                                    shape=input_shape[1:],
                                    initializer='glorot',
                                    trainable=True)
    def call(self, x):
        return x + self.bias

class ConstantTensorInitializer(tf.keras.initializers.Initializer):
  """Initializes tensors to `t`."""

  def __init__(self, t):
    self.t = t

  def __call__(self, shape, dtype=None):
    return self.t

  def get_config(self):
    return {'t': self.t}

class ConstantTensorConstraint(tf.keras.constraints.Constraint):
  """Constrains tensors to `t`."""

  def __init__(self, t):
    self.t = t

  def __call__(self, w):
    return self.t

  def get_config(self):
    return {'t': self.t}

# all you need to create a mask matrix M, which is a NxN identity matrix
# and you can write a contraint like below
class DiagonalWeight(tf.keras.constraints.Constraint):
    """Constrains the weights to be diagonal.
    """
    def __call__(self, w):
        N = K.int_shape(w)[-1]
        m = K.eye(N)
        v = w*m
        return v

# %%
def init_model(nb_hidden_layers, nb_nodes_per_layer, m_periodic, n_periodic, omega, input_dim):

    # Append hidden layers
    all_layers = []

    # Initialize a feedforward neural network
    model = tf.keras.Sequential()

    # Input is two-dimensional (time + one spatial dimension)
    input_model = tf.keras.layers.InputLayer(input_shape= (input_dim,), name='input_model')
    model.add(input_model)

    # Construct first omega matrix
    omega_each_dim = omega*np.ones((input_dim,1))
    Omega_matrix = np.array([])

    for dim in range(input_dim):
        Omega_dim = np.zeros((m_periodic, input_dim))
        Omega_dim[:,dim] = omega_each_dim[dim,0]*np.ones((m_periodic,))
        Omega_matrix = np.vstack([Omega_matrix,Omega_dim]) if Omega_matrix.size else Omega_dim

    Omega = tf.Variable(Omega_matrix.T,dtype=tf.float32)

    # Create first C^inf periodic layers L_p(m,n)
    first_periodic_layer = tf.keras.layers.Dense(m_periodic*input_dim,
                                                 activation = tf.math.cos,
                                                 use_bias = True,
                                                 trainable = True,
                                                 name = 'first_periodic_layer',
                                                 kernel_initializer = ConstantTensorInitializer(Omega),
                                                 kernel_constraint = ConstantTensorConstraint(Omega),
                                                 bias_initializer = 'glorot_normal')
    all_layers.append(first_periodic_layer)
    model.add(first_periodic_layer)

    second_periodic_layer = tf.keras.layers.Dense(m_periodic*input_dim,
                                                  activation = 'tanh',
                                                  use_bias = True,
                                                  trainable = True,
                                                  name = 'second_periodic_layer',
                                                  kernel_constraint = DiagonalWeight(),
                                                  kernel_initializer = 'glorot_normal',
                                                  bias_initializer = 'glorot_normal')
    all_layers.append(second_periodic_layer)
    model.add(second_periodic_layer)

    # create the rest of the network (substitute other code here also)
    for layer in range(nb_hidden_layers):
        if layer == nb_hidden_layers-1:
            layer_name = 'first_to_last_hidden_layer'
        else:
            layer_name = 'hidden_layer_' + str(layer)

        hidden_layer = tf.keras.layers.Dense(nb_nodes_per_layer, 
                                        activation='tanh',
                                        name=layer_name,
                                        kernel_initializer= 'glorot_normal')
                                        #bias_initializer= weight_bias_initializer,
                                        #dtype=tf.float32)
        all_layers.append(hidden_layer)
        model.add(hidden_layer)

    # Output is one-dimensional
    model.add(tf.keras.layers.Dense(1))
    
    return model

# %% [markdown]
# ## high-dimensional second order equation $-\nabla \cdot \left((1+\frac{1}{4}\sin {2\pi x_1}\sin {2\pi x_2})\nabla \Psi\right) + \nu \Psi=-\nabla \cdot \left((1+\frac{1}{4}\sin {2\pi x_1}\sin {2\pi x_2})\nabla \Psi_{exact}(x)\right) + \nu \Psi_{exact}(x)$ with periodic BCs

# %% [markdown]
# ## Exact solution: $\Psi_{exact}(x) = \exp (\sin{2\pi x_1}+ \sin{2\pi x_2})$

# %%
nb_hidden_layers = 3
nb_nodes_per_layer = 30

input_dim = 6
m_periodic = 11
n_periodic = 30

L_period = 1.0 #2*np.pi
omega = 2*np.pi/L_period
# Initialize model aka u_\theta
model5 = init_model(nb_hidden_layers, nb_nodes_per_layer, m_periodic, n_periodic, omega, input_dim)
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_periodic_layer (Dense  (None, 66)               462
#  )
#
#  second_periodic_layer (Dens  (None, 66)               4422
#  e)
#
#  hidden_layer_0 (Dense)      (None, 30)                2010
#
#  hidden_layer_1 (Dense)      (None, 30)                930
#
#  first_to_last_hidden_layer   (None, 30)               930
#  (Dense)
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 8,785
# Trainable params: 8,785
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Sampling

# %%
a = 0
b = 1
N = 2000

nu = 0.5

# Monte Carlo points in the domain

input_data_MC = np.random.uniform(0 ,1, (N,input_dim))

# %% [markdown]
# ## Define the diffusion function and its derivatives here

# %%
def diffusion_fcns(x):
    diffusion = 1 + 1/4 * np.sin(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])
    L,x_dim = np.shape(x)
    grad_diffusion = [np.zeros_like(x[:, 0])] * x_dim
    grad_diffusion[0] = np.pi/2 * np.cos(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])
    grad_diffusion[1] = np.pi/2 * np.sin(2*np.pi*x[:, 0]) * np.cos(2*np.pi*x[:, 1])
    return diffusion, grad_diffusion

# %% [markdown]
# ## Exact solution and its gradient and divergence

# %%
# Define the exact solution
def exact_solu(x):
    y = np.exp(np.sin(2*np.pi*np.double(x[:, 0])) + np.sin(2*np.pi*np.double(x[:, 1])))
    return y

# %%
# Compute the gradient and divergence of the exact solution numerically
def exact_grad_div(x):
    L,x_dim = np.shape(x)
    dx = np.double(0.003)
    gradient = [np.zeros_like(x[:, 0])] * x_dim
    divergence = np.zeros_like(x[:, 0])
    
    for i in range(x_dim):
        dx_i = np.zeros_like(x);
        dx_i[:, i] = 1;
        
            
        # six-order finite difference
        gradient[i] = (-1/60 * exact_solu(x - 3*dx*dx_i) + 3/20 * exact_solu(x - 2*dx*dx_i) - 3/4 * exact_solu(x - dx*dx_i) + 3/4 * exact_solu(x + dx*dx_i) - 3/20 * exact_solu(x + 2*dx*dx_i) + 1/60 * exact_solu(x + 3*dx*dx_i)) / dx
        divergence = divergence + ((1/90) * exact_solu(x - 3*dx*dx_i) -(3/20) * exact_solu(x - 2*dx*dx_i) + (3/2) * exact_solu(x - dx*dx_i) - (49/18) * exact_solu(x) + (3/2) * exact_solu(x + dx*dx_i) - (3/20) * exact_solu(x + 2*dx*dx_i) +(1/90) * exact_solu(x + 3*dx*dx_i)) / dx**2

    return gradient, divergence

# %%
def trainStep_N_dimension(x, diffusion_x, grad_diffusion_x, exact_x, exact_grad_x, exact_div_x, opt, model):
    
    L,x_dim = np.shape(x)
    
    # Outer gradient for model parameters
    with tf.GradientTape() as tape:
        
        # Inner gradient for first derivative of N wrt x
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch(x)
            
            # Inner inner gradient for fi derivative of N wrt x
            with tf.GradientTape(persistent=True) as tape2:
                tape2.watch(x)
            
                N = model(x)
            
            # Gradient of the NN
            grad_N = tape2.gradient(N, x)
            grad_N_i = []
            for i in range(x_dim):
                grad_N_i.append(grad_N[: ,i])
        # Divergence of the NN
        div_N = tf.zeros([L])
        for i in range(x_dim):
            div_N = div_N + tape1.gradient(grad_N_i[i], x)[:, i]
        
            
        
        N = tf.reshape(N, [L])
        
        grad_error = [np.zeros_like(x[:, 0])] * x_dim
        
        # Plug trial solution into ODE:
        divergence_error = div_N - exact_div_x
#         grad_error[0] = grad_N[:, 0] - exact_grad_x[0]
#         grad_error[1] = grad_N[:, 1] - exact_grad_x[1]
        N_error = N - exact_x
        
#         eqn = - (1 + 1/4 * np.sin(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])) *  divergence_error - \
#         (np.pi/2 * np.cos(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])) * grad_error[0] - \
#         (np.pi/2 * np.sin(2*np.pi*x[:, 0]) * np.cos(2*np.pi*x[:, 1])) * grad_error[1] + nu * N_error
        
        eqn = - diffusion_x *  divergence_error  + nu * N_error 
        for i in range(x_dim):
            grad_error[i] = grad_N[:, i] - exact_grad_x[i]
            eqn = eqn - grad_diffusion_x[i] * grad_error[i]
        
        loss = tf.reduce_sum(tf.square(eqn)) 
        N_loss = tf.reduce_sum(tf.square(N_error))
        gradient_loss = tf.square(grad_error[x_dim-1])
        for i in range(x_dim-1):
            gradient_loss = gradient_loss + tf.square(grad_error[i])
        gradient_loss = tf.reduce_sum(gradient_loss)
        divergence_loss = tf.reduce_sum(tf.square(divergence_error))
        
    # Compute the gradient of loss wrt model parameters
    grads = tape.gradient(loss, model.trainable_variables)
    
    # Gradient step
    opt.apply_gradients(zip(grads, model.trainable_variables))
    
    
    return loss, N_loss, gradient_loss, divergence_loss

# %%
def PINNtrain(x, epochs, model):
    
    # optional, use a stopping tolerance (i.e., if loss < 1e-7 then stop training early)
    stop_tol = 1e-12
    
    # set the initial best loss seen so far to something large
    best_loss = 1e12
    best_loss_epoch = -1
    best_weights = None
    
    # Define an optimizer
    lr = tf.keras.optimizers.schedules.PolynomialDecay(0.1, epochs, 1e-4)
    opt = keras.optimizers.Adam()
    epoch_loss, N_loss, gradient_loss, divergence_loss = (np.zeros(epochs) for i in range(4))
    
    # Calculate diffusion function, forcing term at sample points x in double precision
    diffusion_x, grad_diffusion_x = diffusion_fcns(np.double(x.numpy()))
    exact_x = exact_solu(np.double(x.numpy()))
    exact_grad_x, exact_div_x = exact_grad_div(np.double(x.numpy()))
    
    # Main training loop
    for i in range(epochs):
        
        epoch_loss[i], N_loss[i], gradient_loss[i], divergence_loss[i]  = trainStep_N_dimension(x, diffusion_x, grad_diffusion_x, exact_x, exact_grad_x, exact_div_x, opt, model)
        
        if (np.mod(i, 100)==0):
          print("PDE loss in {}th epoch: {: 1.6e}. Last save epoch and best loss so far: {}, {: 1.6e}.".format(i, epoch_loss[i], best_loss_epoch, best_loss))
    
        if (epoch_loss[i] < best_loss):
            best_weights = model.get_weights()
            best_loss_epoch = i
            best_loss = epoch_loss[i]
            #print("Found a new best local minimum at epoch {}: loss {: 1.6e}. Saving weights.".format(i, epoch_loss[i]))
            
        if (epoch_loss[i] < stop_tol):
            print("Current model has loss {: 1.6e}, lower than stopping tolerance {: 1.6e}, stopping early at epoch {}.".format(epoch_loss[i],stop_tol,i))
            return epoch_loss, N_loss, gradient_loss, divergence_loss
    
    if (best_loss < epoch_loss[i]):
        model.set_weights(best_weights)
        print("Current loss {: 1.6e}, Best loss {: 1.6e}. Restoring best model weights.".format(epoch_loss[i],best_loss))
    else:
        print("Current loss {: 1.6e}, Best loss {: 1.6e}. Keeping current model weights.".format(epoch_loss[i],best_loss))
        
    return epoch_loss, N_loss, gradient_loss, divergence_loss

# %%
# train NN for Monte Carlo sample
epochs = 10000
PDE_loss1, N_loss1, gradient_loss1, divergence_loss1 = PINNtrain(tf.convert_to_tensor(input_data_MC, dtype = float), epochs, model5)
# Out:
# PDE loss in 0th epoch:  3.546594e+07. Last save epoch and best loss so far: -1,  1.000000e+12.
# PDE loss in 100th epoch:  8.687420e+06. Last save epoch and best loss so far: 99,  9.090109e+06.
# PDE loss in 200th epoch:  1.903475e+05. Last save epoch and best loss so far: 199,  1.937806e+05.
# PDE loss in 300th epoch:  6.426778e+04. Last save epoch and best loss so far: 299,  6.440452e+04.
# PDE loss in 400th epoch:  3.914405e+04. Last save epoch and best loss so far: 399,  3.930088e+04.
# PDE loss in 500th epoch:  2.808851e+04. Last save epoch and best loss so far: 499,  2.816560e+04.
# PDE loss in 600th epoch:  2.201432e+04. Last save epoch and best loss so far: 599,  2.206902e+04.
# PDE loss in 700th epoch:  2.896859e+04. Last save epoch and best loss so far: 689,  1.853583e+04.
# PDE loss in 800th epoch:  1.555570e+04. Last save epoch and best loss so far: 799,  1.557689e+04.
# PDE loss in 900th epoch:  1.439020e+04. Last save epoch and best loss so far: 898,  1.376460e+04.
# PDE loss in 1000th epoch:  1.228352e+04. Last save epoch and best loss so far: 999,  1.229687e+04.
# PDE loss in 1100th epoch:  1.125943e+04. Last save epoch and best loss so far: 1089,  1.120316e+04.
# PDE loss in 1200th epoch:  9.934096e+03. Last save epoch and best loss so far: 1199,  9.944483e+03.
# PDE loss in 1300th epoch:  8.941304e+03. Last save epoch and best loss so far: 1299,  8.950788e+03.
# PDE loss in 1400th epoch:  8.048012e+03. Last save epoch and best loss so far: 1399,  8.064006e+03.
# PDE loss in 1500th epoch:  7.228863e+03. Last save epoch and best loss so far: 1499,  7.236583e+03.
# PDE loss in 1600th epoch:  2.055530e+04. Last save epoch and best loss so far: 1587,  6.602809e+03.
# PDE loss in 1700th epoch:  5.824198e+03. Last save epoch and best loss so far: 1699,  5.830658e+03.
# PDE loss in 1800th epoch:  5.225722e+03. Last save epoch and best loss so far: 1799,  5.231420e+03.
# PDE loss in 1900th epoch:  4.749494e+03. Last save epoch and best loss so far: 1897,  4.706612e+03.
# PDE loss in 2000th epoch:  4.179556e+03. Last save epoch and best loss so far: 1999,  4.183993e+03.
# PDE loss in 2100th epoch:  3.735904e+03. Last save epoch and best loss so far: 2099,  3.740118e+03.
# PDE loss in 2200th epoch:  3.333167e+03. Last save epoch and best loss so far: 2199,  3.337016e+03.
# PDE loss in 2300th epoch:  1.378059e+04. Last save epoch and best loss so far: 2286,  3.022732e+03.
# PDE loss in 2400th epoch:  2.631564e+03. Last save epoch and best loss so far: 2399,  2.635130e+03.
# PDE loss in 2500th epoch:  2.337902e+03. Last save epoch and best loss so far: 2499,  2.340713e+03.
# PDE loss in 2600th epoch:  2.333797e+03. Last save epoch and best loss so far: 2592,  2.098877e+03.
# PDE loss in 2700th epoch:  1.835650e+03. Last save epoch and best loss so far: 2699,  1.838170e+03.
# PDE loss in 2800th epoch:  1.627560e+03. Last save epoch and best loss so far: 2799,  1.629502e+03.
# PDE loss in 2900th epoch:  2.506719e+04. Last save epoch and best loss so far: 2882,  1.478147e+03.
# PDE loss in 3000th epoch:  1.280472e+03. Last save epoch and best loss so far: 2999,  1.282162e+03.
# PDE loss in 3100th epoch:  1.139951e+03. Last save epoch and best loss so far: 3099,  1.141268e+03.
# PDE loss in 3200th epoch:  1.165468e+03. Last save epoch and best loss so far: 3190,  1.031462e+03.
# PDE loss in 3300th epoch:  9.097740e+02. Last save epoch and best loss so far: 3299,  9.118064e+02.
# PDE loss in 3400th epoch:  8.160488e+02. Last save epoch and best loss so far: 3399,  8.169156e+02.
# PDE loss in 3500th epoch:  3.270323e+03. Last save epoch and best loss so far: 3492,  7.579229e+02.
# PDE loss in 3600th epoch:  6.651112e+02. Last save epoch and best loss so far: 3599,  6.658394e+02.
# PDE loss in 3700th epoch:  6.036188e+02. Last save epoch and best loss so far: 3699,  6.049451e+02.
# PDE loss in 3800th epoch:  5.539396e+02. Last save epoch and best loss so far: 3795,  5.548606e+02.
# PDE loss in 3900th epoch:  5.045815e+02. Last save epoch and best loss so far: 3899,  5.050272e+02.
# PDE loss in 4000th epoch:  8.205800e+03. Last save epoch and best loss so far: 3972,  4.748297e+02.
# PDE loss in 4100th epoch:  4.297268e+02. Last save epoch and best loss so far: 4099,  4.299815e+02.
# PDE loss in 4200th epoch:  4.036008e+02. Last save epoch and best loss so far: 4189,  4.005325e+02.
# PDE loss in 4300th epoch:  3.765253e+02. Last save epoch and best loss so far: 4289,  3.757541e+02.
# PDE loss in 4400th epoch:  3.441628e+02. Last save epoch and best loss so far: 4399,  3.444239e+02.
# PDE loss in 4500th epoch:  6.849560e+03. Last save epoch and best loss so far: 4465,  3.281317e+02.
# PDE loss in 4600th epoch:  3.039862e+02. Last save epoch and best loss so far: 4599,  3.043145e+02.
# PDE loss in 4700th epoch:  2.842389e+02. Last save epoch and best loss so far: 4699,  2.841623e+02.
# PDE loss in 4800th epoch:  2.687357e+02. Last save epoch and best loss so far: 4790,  2.736707e+02.
# PDE loss in 4900th epoch:  3.657296e+02. Last save epoch and best loss so far: 4832,  2.623137e+02.
# PDE loss in 5000th epoch:  2.390711e+02. Last save epoch and best loss so far: 4999,  2.391372e+02.
# PDE loss in 5100th epoch:  2.327625e+02. Last save epoch and best loss so far: 5099,  2.298306e+02.
# PDE loss in 5200th epoch:  4.022992e+02. Last save epoch and best loss so far: 5163,  2.205324e+02.
# PDE loss in 5300th epoch:  2.606832e+02. Last save epoch and best loss so far: 5296,  2.102709e+02.
# PDE loss in 5400th epoch:  1.962708e+02. Last save epoch and best loss so far: 5399,  1.963821e+02.
# PDE loss in 5500th epoch:  4.649226e+03. Last save epoch and best loss so far: 5463,  1.893972e+02.
# PDE loss in 5600th epoch:  1.844562e+02. Last save epoch and best loss so far: 5599,  1.845377e+02.
# PDE loss in 5700th epoch:  1.737812e+02. Last save epoch and best loss so far: 5699,  1.738802e+02.
# PDE loss in 5800th epoch:  1.749315e+02. Last save epoch and best loss so far: 5790,  1.666478e+02.
# PDE loss in 5900th epoch:  1.673244e+02. Last save epoch and best loss so far: 5894,  1.631933e+02.
# PDE loss in 6000th epoch:  1.518741e+02. Last save epoch and best loss so far: 5999,  1.519531e+02.
# PDE loss in 6100th epoch:  1.750871e+02. Last save epoch and best loss so far: 6011,  1.511931e+02.
# PDE loss in 6200th epoch:  1.420496e+02. Last save epoch and best loss so far: 6199,  1.421265e+02.
# PDE loss in 6300th epoch:  1.347906e+03. Last save epoch and best loss so far: 6244,  1.389168e+02.
# PDE loss in 6400th epoch:  6.966281e+03. Last save epoch and best loss so far: 6373,  1.329058e+02.
# PDE loss in 6500th epoch:  1.289825e+02. Last save epoch and best loss so far: 6494,  1.289772e+02.
# PDE loss in 6600th epoch:  1.541816e+02. Last save epoch and best loss so far: 6587,  1.230541e+02.
# PDE loss in 6700th epoch:  1.242351e+02. Last save epoch and best loss so far: 6697,  1.222312e+02.
# PDE loss in 6800th epoch:  1.155092e+02. Last save epoch and best loss so far: 6799,  1.155656e+02.
# PDE loss in 6900th epoch:  1.717545e+02. Last save epoch and best loss so far: 6818,  1.146093e+02.
# PDE loss in 7000th epoch:  5.149285e+02. Last save epoch and best loss so far: 6931,  1.108494e+02.
# PDE loss in 7100th epoch:  1.047348e+02. Last save epoch and best loss so far: 7099,  1.047812e+02.
# PDE loss in 7200th epoch:  1.223250e+02. Last save epoch and best loss so far: 7106,  1.045269e+02.
# PDE loss in 7300th epoch:  1.005550e+02. Last save epoch and best loss so far: 7299,  1.006066e+02.
# PDE loss in 7400th epoch:  9.215777e+02. Last save epoch and best loss so far: 7358,  9.787209e+01.
# PDE loss in 7500th epoch:  1.200640e+03. Last save epoch and best loss so far: 7451,  9.698120e+01.
# PDE loss in 7600th epoch:  1.787249e+03. Last save epoch and best loss so far: 7543,  9.334050e+01.
# PDE loss in 7700th epoch:  9.553763e+01. Last save epoch and best loss so far: 7689,  9.038065e+01.
# PDE loss in 7800th epoch:  8.909809e+01. Last save epoch and best loss so far: 7799,  8.848456e+01.
# PDE loss in 7900th epoch:  2.025742e+03. Last save epoch and best loss so far: 7857,  8.596371e+01.
# PDE loss in 8000th epoch:  9.098663e+01. Last save epoch and best loss so far: 7967,  8.397432e+01.
# PDE loss in 8100th epoch:  8.503194e+01. Last save epoch and best loss so far: 8096,  8.208265e+01.
# PDE loss in 8200th epoch:  4.819013e+03. Last save epoch and best loss so far: 8177,  7.891718e+01.
# PDE loss in 8300th epoch:  7.989956e+01. Last save epoch and best loss so far: 8177,  7.891718e+01.
# PDE loss in 8400th epoch:  4.194106e+02. Last save epoch and best loss so far: 8368,  7.690123e+01.
# PDE loss in 8500th epoch:  7.920582e+02. Last save epoch and best loss so far: 8449,  7.462806e+01.
# PDE loss in 8600th epoch:  7.283810e+01. Last save epoch and best loss so far: 8598,  7.283381e+01.
# PDE loss in 8700th epoch:  1.803174e+04. Last save epoch and best loss so far: 8672,  7.038397e+01.
# PDE loss in 8800th epoch:  7.245637e+01. Last save epoch and best loss so far: 8672,  7.038397e+01.
# PDE loss in 8900th epoch:  1.793884e+02. Last save epoch and best loss so far: 8885,  6.879663e+01.
# PDE loss in 9000th epoch:  1.607932e+02. Last save epoch and best loss so far: 8966,  6.671136e+01.
# PDE loss in 9100th epoch:  6.750546e+01. Last save epoch and best loss so far: 9095,  6.649910e+01.
# PDE loss in 9200th epoch:  6.318984e+01. Last save epoch and best loss so far: 9199,  6.319518e+01.
# PDE loss in 9300th epoch:  7.420134e+01. Last save epoch and best loss so far: 9200,  6.318984e+01.
# PDE loss in 9400th epoch:  1.009055e+02. Last save epoch and best loss so far: 9387,  6.209352e+01.
# PDE loss in 9500th epoch:  1.325954e+02. Last save epoch and best loss so far: 9485,  5.990152e+01.
# PDE loss in 9600th epoch:  6.146895e+01. Last save epoch and best loss so far: 9485,  5.990152e+01.
# PDE loss in 9700th epoch:  5.773315e+01. Last save epoch and best loss so far: 9699,  5.775954e+01.
# PDE loss in 9800th epoch:  1.045208e+02. Last save epoch and best loss so far: 9729,  5.704388e+01.
# PDE loss in 9900th epoch:  5.669781e+01. Last save epoch and best loss so far: 9899,  5.672350e+01.
# Current loss  5.543969e+01, Best loss  5.543969e+01. Keeping current model weights.

# %% [markdown]
# ## Loss vs. number of epochs

# %%
fig = plt.figure(1)
plt.semilogy(range(0, epochs), PDE_loss1)
plt.xlabel('epochs')
plt.ylabel('loss')

plt.grid()
plt.show()

# %% [markdown]
# ## Errors vs. epochs

# %%
fig = plt.figure(2)
plt.semilogy(range(0, epochs), PDE_loss1, range(0, epochs), N_loss1, range(0, epochs), gradient_loss1, range(0, epochs), divergence_loss1)
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['PDE','function','gradient','divergence'])

plt.grid()
plt.show()

# %% [markdown]
# ## Relative $L^2$ error. (Calculate using Monte-Carlo)

# %%
# relative L^2 error
input_data_MC = np.random.uniform(0 ,1, (2*N,input_dim))
z_model = model5(input_data_MC)
z_model = tf.reshape(z_model, [2*N])
z_exact = exact_solu(input_data_MC)
error = np.sqrt(sum(np.square(z_model - z_exact)))/np.sqrt(sum(np.square(z_exact)))
print(error)
# Out:
# 0.0024997699701452647

# %%
plt.plot(z_model-z_exact)

# %% [markdown]
# ## Compare the NN results with the exact solution

# %%
# Define x3,x4,x5,x6 here
M_plot = 50
x3, x4, x5, x6 = 0, 0, -0.03, 0

x = np.outer(np.linspace(0,1,M_plot), np.ones(M_plot))
y = x.copy().T
z_true = np.exp(np.sin(2*np.pi*x) + np.sin(2*np.pi*y))

x = x.reshape(M_plot**2,1)
y = y.reshape(M_plot**2,1)
x3 = x3* np.ones((M_plot**2,1))
x4 = x4* np.ones((M_plot**2,1))
x5 = x5* np.ones((M_plot**2,1))
x6 = x6* np.ones((M_plot**2,1))
z_model = model5(np.concatenate((x, y, x3, x4, x5, x6), axis=1))
z_model = z_model.numpy().reshape(M_plot,M_plot)

# %%
fig = plt.figure()
ax1 = plt.axes(projection='3d')
x = x.reshape(M_plot,M_plot)
y = y.reshape(M_plot,M_plot)
function_error = z_model - z_true
ax1.plot_wireframe(x,y,function_error)
ax1.view_init(20,45)
ax1.set_title("Error original function")
# Out:
# Text(0.5, 0.92, 'Error original function')
