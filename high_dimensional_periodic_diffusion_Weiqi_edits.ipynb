# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
np.set_printoptions(precision = 3, suppress = True)

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-2-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
from keras import backend as K

class BiasLayer(tf.keras.layers.Layer):
    def __init__(self, *args, **kwargs):
        super(BiasLayer, self).__init__(*args, **kwargs)

    def build(self, input_shape):
        print(input_shape)
        self.bias = self.add_weight('bias',
                                    shape=input_shape[1:],
                                    initializer='glorot',
                                    trainable=True)
    def call(self, x):
        return x + self.bias

class ConstantTensorInitializer(tf.keras.initializers.Initializer):
  """Initializes tensors to `t`."""

  def __init__(self, t):
    self.t = t

  def __call__(self, shape, dtype=None):
    return self.t

  def get_config(self):
    return {'t': self.t}

class ConstantTensorConstraint(tf.keras.constraints.Constraint):
  """Constrains tensors to `t`."""

  def __init__(self, t):
    self.t = t

  def __call__(self, w):
    return self.t

  def get_config(self):
    return {'t': self.t}

# all you need to create a mask matrix M, which is a NxN identity matrix
# and you can write a contraint like below
class DiagonalWeight(tf.keras.constraints.Constraint):
    """Constrains the weights to be diagonal.
    """
    def __call__(self, w):
        N = K.int_shape(w)[-1]
        m = K.eye(N)
        v = w*m
        return v

# %%
def init_model(nb_hidden_layers, nb_nodes_per_layer, m_periodic, n_periodic, omega, input_dim):

    # Append hidden layers
    all_layers = []

    # Initialize a feedforward neural network
    model = tf.keras.Sequential()

    # Input is two-dimensional (time + one spatial dimension)
    input_model = tf.keras.layers.InputLayer(input_shape= (input_dim,), name='input_model')
    model.add(input_model)

    # Construct first omega matrix
    omega_each_dim = omega*np.ones((input_dim,1))
    Omega_matrix = np.array([])

    for dim in range(input_dim):
        Omega_dim = np.zeros((m_periodic, input_dim))
        Omega_dim[:,dim] = omega_each_dim[dim,0]*np.ones((m_periodic,))
        Omega_matrix = np.vstack([Omega_matrix,Omega_dim]) if Omega_matrix.size else Omega_dim

    Omega = tf.Variable(Omega_matrix.T,dtype=tf.float32)

    # Create first C^inf periodic layers L_p(m,n)
    first_periodic_layer = tf.keras.layers.Dense(m_periodic*input_dim,
                                                 activation = tf.math.cos,
                                                 use_bias = True,
                                                 trainable = True,
                                                 name = 'first_periodic_layer',
                                                 kernel_initializer = ConstantTensorInitializer(Omega),
                                                 kernel_constraint = ConstantTensorConstraint(Omega),
                                                 bias_initializer = 'glorot_normal')
    all_layers.append(first_periodic_layer)
    model.add(first_periodic_layer)

    second_periodic_layer = tf.keras.layers.Dense(m_periodic*input_dim,
                                                  activation = 'tanh',
                                                  use_bias = True,
                                                  trainable = True,
                                                  name = 'second_periodic_layer',
                                                  kernel_constraint = DiagonalWeight(),
                                                  kernel_initializer = 'glorot_normal',
                                                  bias_initializer = 'glorot_normal')
    all_layers.append(second_periodic_layer)
    model.add(second_periodic_layer)

    # create the rest of the network (substitute other code here also)
    for layer in range(nb_hidden_layers):
        if layer == nb_hidden_layers-1:
            layer_name = 'first_to_last_hidden_layer'
        else:
            layer_name = 'hidden_layer_' + str(layer)

        hidden_layer = tf.keras.layers.Dense(nb_nodes_per_layer, 
                                        activation='tanh',
                                        name=layer_name,
                                        kernel_initializer= 'glorot_normal')
                                        #bias_initializer= weight_bias_initializer,
                                        #dtype=tf.float32)
        all_layers.append(hidden_layer)
        model.add(hidden_layer)

    # Output is one-dimensional
    model.add(tf.keras.layers.Dense(1))
    
    return model

# %% [markdown]
# ## high-dimensional second order equation $-\nabla \cdot \left((1+\frac{1}{4}\sin {2\pi x_1}\sin {2\pi x_2})\nabla \Psi\right) + \nu \Psi=- 2\pi^2 \cos{2\pi x_1}\cos{4\pi x_1}\sin^2 {2\pi x_2} - \pi^2 \sin{2\pi x_1}\sin{4\pi x_1}\cos^2 {2\pi x_2} + 20\pi^2(1+\frac{1}{4}\sin {2\pi x_1}\sin {2\pi x_2})\sin{4\pi x_1}\sin{4\pi x_2} + \nu \sin{4\pi x_1}\sin{2\pi x_2}$ with periodic BCs

# %% [markdown]
# ## Exact solution: $\Psi(x) = \sin{4\pi x_1} \sin{2\pi x_2}$

# %%
nb_hidden_layers = 3
nb_nodes_per_layer = 30

input_dim = 6
m_periodic = 11
n_periodic = 30

L_period = 1.0 #2*np.pi
omega = 2*np.pi/L_period
# Initialize model aka u_\theta
model5 = init_model(nb_hidden_layers, nb_nodes_per_layer, m_periodic, n_periodic, omega, input_dim)
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_periodic_layer (Dense  (None, 66)               462
#  )
#
#  second_periodic_layer (Dens  (None, 66)               4422
#  e)
#
#  hidden_layer_0 (Dense)      (None, 30)                2010
#
#  hidden_layer_1 (Dense)      (None, 30)                930
#
#  first_to_last_hidden_layer   (None, 30)               930
#  (Dense)
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 8,785
# Trainable params: 8,785
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Sampling

# %%
a = 0
b = 1
N = 2000

nu = 0.5

# Monte Carlo points in the domain

input_data_MC = np.random.uniform(0 ,1, (N,input_dim))

# %%
def trainStep_N_dimension(x, opt, model):
    
    L,x_dim = np.shape(x)
    
    # Outer gradient for model parameters
    with tf.GradientTape() as tape:
        
        # Inner gradient for first derivative of N wrt x
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch(x)
            
            # Inner inner gradient for fi derivative of N wrt x
            with tf.GradientTape(persistent=True) as tape2:
                tape2.watch(x)
            
                N = model(x)
            
            # Gradient of the NN
            grad_N = tape2.gradient(N, x)
            grad_N_i = []
            for i in range(x_dim):
                grad_N_i.append(grad_N[: ,i])
        # Divergence of the NN
        div_N = tf.zeros([L])
        for i in range(x_dim):
            div_N = div_N + tape1.gradient(grad_N_i[i], x)[:, i]
            
        
        N = tf.reshape(N, [L])
        # Plug trial solution into ODE:
        divergence_error = div_N + 20 * np.pi**2 * np.sin(4*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])
        Nx_error = grad_N[:, 0] - 4 * np.pi * np.cos(4*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])
        Ny_error = grad_N[:, 1] - 2 * np.pi * np.sin(4*np.pi*x[:, 0]) * np.cos(2*np.pi*x[:, 1])
        N_error = N - np.sin(4*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])
        
        eqn = - (1 + 1/4 * np.sin(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])) *  divergence_error - \
        (np.pi/2 * np.cos(2*np.pi*x[:, 0]) * np.sin(2*np.pi*x[:, 1])) * Nx_error - \
        (np.pi/2 * np.sin(2*np.pi*x[:, 0]) * np.cos(2*np.pi*x[:, 1])) * Ny_error + nu * N_error
        
        loss = tf.reduce_sum(tf.square(eqn)) 
        N_loss = tf.reduce_sum(tf.square(N_error))
        gradient_loss =  tf.reduce_sum(tf.square(Nx_error) + tf.square(Ny_error))
        divergence_loss = tf.reduce_sum(tf.square(divergence_error))
        
    # Compute the gradient of loss wrt model parameters
    grads = tape.gradient(loss, model.trainable_variables)
    
    # Gradient step
    opt.apply_gradients(zip(grads, model.trainable_variables))
    
    
    return loss, N_loss, gradient_loss, divergence_loss

# %%
def PINNtrain(x, epochs, model):
    
    # optional, use a stopping tolerance (i.e., if loss < 1e-7 then stop training early)
    stop_tol = 1e-12
    
    # set the initial best loss seen so far to something large
    best_loss = 1e12
    best_loss_epoch = -1
    best_weights = None
    
    # Define an optimizer
    lr = tf.keras.optimizers.schedules.PolynomialDecay(0.1, epochs, 1e-4)
    opt = keras.optimizers.Adam()
    epoch_loss, N_loss, gradient_loss, divergence_loss = (np.zeros(epochs) for i in range(4))
    
    # Main training loop
    for i in range(epochs):
        
        epoch_loss[i], N_loss[i], gradient_loss[i], divergence_loss[i]  = trainStep_N_dimension(x ,opt, model)
        
        if (np.mod(i, 100)==0):
          print("PDE loss in {}th epoch: {: 1.6e}. Last save epoch and best loss so far: {}, {: 1.6e}.".format(i, epoch_loss[i], best_loss_epoch, best_loss))
    
        if (epoch_loss[i] < best_loss):
            best_weights = model.get_weights()
            best_loss_epoch = i
            best_loss = epoch_loss[i]
            #print("Found a new best local minimum at epoch {}: loss {: 1.6e}. Saving weights.".format(i, epoch_loss[i]))
            
        if (epoch_loss[i] < stop_tol):
            print("Current model has loss {: 1.6e}, lower than stopping tolerance {: 1.6e}, stopping early at epoch {}.".format(epoch_loss[i],stop_tol,i))
            return epoch_loss, N_loss, gradient_loss, divergence_loss
    
    if (best_loss < epoch_loss[i]):
        model.set_weights(best_weights)
        print("Current loss {: 1.6e}, Best loss {: 1.6e}. Restoring best model weights.".format(epoch_loss[i],best_loss))
    else:
        print("Current loss {: 1.6e}, Best loss {: 1.6e}. Keeping current model weights.".format(epoch_loss[i],best_loss))
        
    return epoch_loss, N_loss, gradient_loss, divergence_loss

# %%
# train NN for Monte Carlo sample
epochs = 20000
PDE_loss1, N_loss1, gradient_loss1, divergence_loss1 = PINNtrain(tf.convert_to_tensor(input_data_MC, dtype = float), epochs, model5)
# Out:
# PDE loss in 0th epoch:  2.077225e+07. Last save epoch and best loss so far: -1,  1.000000e+12.
# PDE loss in 100th epoch:  1.862919e+07. Last save epoch and best loss so far: 99,  1.864648e+07.
# PDE loss in 200th epoch:  1.461734e+07. Last save epoch and best loss so far: 199,  1.472375e+07.
# PDE loss in 300th epoch:  2.464664e+06. Last save epoch and best loss so far: 299,  2.535654e+06.
# PDE loss in 400th epoch:  1.849861e+05. Last save epoch and best loss so far: 399,  1.846950e+05.
# PDE loss in 500th epoch:  5.803638e+04. Last save epoch and best loss so far: 499,  5.851035e+04.
# PDE loss in 600th epoch:  3.027374e+04. Last save epoch and best loss so far: 599,  3.042920e+04.
# PDE loss in 700th epoch:  1.931409e+04. Last save epoch and best loss so far: 699,  1.952387e+04.
# PDE loss in 800th epoch:  1.453940e+04. Last save epoch and best loss so far: 795,  1.388515e+04.
# PDE loss in 900th epoch:  1.033131e+04. Last save epoch and best loss so far: 897,  1.024983e+04.
# PDE loss in 1000th epoch:  7.969987e+03. Last save epoch and best loss so far: 999,  7.970790e+03.
# PDE loss in 1100th epoch:  6.346777e+03. Last save epoch and best loss so far: 1099,  6.418859e+03.
# PDE loss in 1200th epoch:  5.195288e+03. Last save epoch and best loss so far: 1199,  5.207112e+03.
# PDE loss in 1300th epoch:  4.618770e+03. Last save epoch and best loss so far: 1293,  4.561226e+03.
# PDE loss in 1400th epoch:  4.724471e+03. Last save epoch and best loss so far: 1397,  3.731155e+03.
# PDE loss in 1500th epoch:  5.807571e+03. Last save epoch and best loss so far: 1472,  3.445606e+03.
# PDE loss in 1600th epoch:  2.836760e+03. Last save epoch and best loss so far: 1593,  2.843105e+03.
# PDE loss in 1700th epoch:  2.502980e+03. Last save epoch and best loss so far: 1699,  2.504096e+03.
# PDE loss in 1800th epoch:  2.391029e+03. Last save epoch and best loss so far: 1793,  2.302476e+03.
# PDE loss in 1900th epoch:  2.173361e+03. Last save epoch and best loss so far: 1889,  2.066684e+03.
# PDE loss in 2000th epoch:  2.637616e+03. Last save epoch and best loss so far: 1958,  1.917082e+03.
# PDE loss in 2100th epoch:  1.733850e+03. Last save epoch and best loss so far: 2093,  1.691457e+03.
# PDE loss in 2200th epoch:  5.201669e+03. Last save epoch and best loss so far: 2176,  1.575084e+03.
# PDE loss in 2300th epoch:  1.489421e+03. Last save epoch and best loss so far: 2293,  1.482173e+03.
# PDE loss in 2400th epoch:  1.321620e+03. Last save epoch and best loss so far: 2399,  1.321490e+03.
# PDE loss in 2500th epoch:  1.545871e+03. Last save epoch and best loss so far: 2455,  1.318684e+03.
# PDE loss in 2600th epoch:  1.208785e+03. Last save epoch and best loss so far: 2577,  1.202999e+03.
# PDE loss in 2700th epoch:  3.865066e+03. Last save epoch and best loss so far: 2673,  1.098139e+03.
# PDE loss in 2800th epoch:  1.118824e+03. Last save epoch and best loss so far: 2792,  1.042169e+03.
# PDE loss in 2900th epoch:  7.547965e+03. Last save epoch and best loss so far: 2858,  9.757428e+02.
# PDE loss in 3000th epoch:  4.697519e+03. Last save epoch and best loss so far: 2982,  9.102063e+02.
# PDE loss in 3100th epoch:  2.147391e+03. Last save epoch and best loss so far: 3064,  8.722813e+02.
# PDE loss in 3200th epoch:  8.149658e+02. Last save epoch and best loss so far: 3195,  8.122236e+02.
# PDE loss in 3300th epoch:  1.239821e+03. Last save epoch and best loss so far: 3279,  7.848135e+02.
# PDE loss in 3400th epoch:  7.534646e+02. Last save epoch and best loss so far: 3349,  7.680813e+02.
# PDE loss in 3500th epoch:  1.600074e+03. Last save epoch and best loss so far: 3458,  7.205185e+02.
# PDE loss in 3600th epoch:  7.284620e+02. Last save epoch and best loss so far: 3595,  6.967139e+02.
# PDE loss in 3700th epoch:  6.940162e+02. Last save epoch and best loss so far: 3695,  6.567424e+02.
# PDE loss in 3800th epoch:  6.198337e+02. Last save epoch and best loss so far: 3789,  6.190366e+02.
# PDE loss in 3900th epoch:  2.367300e+03. Last save epoch and best loss so far: 3789,  6.190366e+02.
# PDE loss in 4000th epoch:  8.207991e+02. Last save epoch and best loss so far: 3950,  5.869550e+02.
# PDE loss in 4100th epoch:  9.321265e+02. Last save epoch and best loss so far: 4056,  5.761225e+02.
# PDE loss in 4200th epoch:  5.832583e+02. Last save epoch and best loss so far: 4193,  5.596026e+02.
# PDE loss in 4300th epoch:  6.381147e+02. Last save epoch and best loss so far: 4297,  5.562563e+02.
# PDE loss in 4400th epoch:  1.078404e+03. Last save epoch and best loss so far: 4312,  5.202874e+02.
# PDE loss in 4500th epoch:  4.958719e+02. Last save epoch and best loss so far: 4426,  4.934534e+02.
# PDE loss in 4600th epoch:  4.986832e+02. Last save epoch and best loss so far: 4426,  4.934534e+02.
# PDE loss in 4700th epoch:  4.915361e+02. Last save epoch and best loss so far: 4611,  4.661522e+02.
# PDE loss in 4800th epoch:  5.031189e+02. Last save epoch and best loss so far: 4746,  4.453514e+02.
# PDE loss in 4900th epoch:  4.301473e+02. Last save epoch and best loss so far: 4894,  4.321538e+02.
# PDE loss in 5000th epoch:  4.339846e+02. Last save epoch and best loss so far: 4943,  4.203678e+02.
# PDE loss in 5100th epoch:  4.249080e+02. Last save epoch and best loss so far: 5093,  4.071133e+02.
# PDE loss in 5200th epoch:  4.553630e+02. Last save epoch and best loss so far: 5093,  4.071133e+02.
# PDE loss in 5300th epoch:  4.719946e+02. Last save epoch and best loss so far: 5291,  4.009132e+02.
# PDE loss in 5400th epoch:  5.254291e+02. Last save epoch and best loss so far: 5291,  4.009132e+02.
# PDE loss in 5500th epoch:  7.222276e+02. Last save epoch and best loss so far: 5431,  3.765801e+02.
# PDE loss in 5600th epoch:  1.032926e+03. Last save epoch and best loss so far: 5555,  3.593915e+02.
# PDE loss in 5700th epoch:  1.242659e+03. Last save epoch and best loss so far: 5621,  3.574355e+02.
# PDE loss in 5800th epoch:  6.479067e+02. Last save epoch and best loss so far: 5749,  3.497879e+02.
# PDE loss in 5900th epoch:  8.321576e+02. Last save epoch and best loss so far: 5749,  3.497879e+02.
# PDE loss in 6000th epoch:  2.057148e+03. Last save epoch and best loss so far: 5970,  3.257645e+02.
# PDE loss in 6100th epoch:  1.589114e+03. Last save epoch and best loss so far: 6054,  3.255047e+02.
# PDE loss in 6200th epoch:  4.835121e+02. Last save epoch and best loss so far: 6139,  3.249146e+02.
# PDE loss in 6300th epoch:  4.952141e+02. Last save epoch and best loss so far: 6251,  3.193835e+02.
# PDE loss in 6400th epoch:  3.271669e+02. Last save epoch and best loss so far: 6396,  3.099128e+02.
# PDE loss in 6500th epoch:  3.018752e+02. Last save epoch and best loss so far: 6421,  2.972225e+02.
# PDE loss in 6600th epoch:  2.893188e+02. Last save epoch and best loss so far: 6596,  2.859825e+02.
# PDE loss in 6700th epoch:  2.806845e+02. Last save epoch and best loss so far: 6694,  2.805411e+02.
# PDE loss in 6800th epoch:  2.923160e+02. Last save epoch and best loss so far: 6729,  2.775473e+02.
# PDE loss in 6900th epoch:  2.866495e+02. Last save epoch and best loss so far: 6895,  2.719213e+02.
# PDE loss in 7000th epoch:  2.910101e+02. Last save epoch and best loss so far: 6904,  2.691815e+02.
# PDE loss in 7100th epoch:  3.218811e+02. Last save epoch and best loss so far: 7083,  2.607152e+02.
# PDE loss in 7200th epoch:  2.566158e+03. Last save epoch and best loss so far: 7168,  2.565580e+02.
# PDE loss in 7300th epoch:  4.235604e+02. Last save epoch and best loss so far: 7168,  2.565580e+02.
# PDE loss in 7400th epoch:  4.566538e+02. Last save epoch and best loss so far: 7168,  2.565580e+02.
# PDE loss in 7500th epoch:  3.320718e+03. Last save epoch and best loss so far: 7168,  2.565580e+02.
# PDE loss in 7600th epoch:  3.219241e+02. Last save epoch and best loss so far: 7535,  2.489537e+02.
# PDE loss in 7700th epoch:  2.942485e+02. Last save epoch and best loss so far: 7625,  2.464595e+02.
# PDE loss in 7800th epoch:  2.278939e+03. Last save epoch and best loss so far: 7705,  2.410161e+02.
# PDE loss in 7900th epoch:  4.706760e+02. Last save epoch and best loss so far: 7705,  2.410161e+02.
# PDE loss in 8000th epoch:  2.088576e+03. Last save epoch and best loss so far: 7705,  2.410161e+02.
# PDE loss in 8100th epoch:  2.965599e+02. Last save epoch and best loss so far: 8080,  2.239016e+02.
# PDE loss in 8200th epoch:  5.348774e+02. Last save epoch and best loss so far: 8148,  2.222341e+02.
# PDE loss in 8300th epoch:  3.700184e+02. Last save epoch and best loss so far: 8239,  2.130763e+02.
# PDE loss in 8400th epoch:  4.417868e+03. Last save epoch and best loss so far: 8360,  2.087301e+02.
# PDE loss in 8500th epoch:  5.462836e+02. Last save epoch and best loss so far: 8468,  2.060715e+02.
# PDE loss in 8600th epoch:  2.053928e+02. Last save epoch and best loss so far: 8583,  2.016579e+02.
# PDE loss in 8700th epoch:  1.618972e+03. Last save epoch and best loss so far: 8583,  2.016579e+02.
# PDE loss in 8800th epoch:  3.682843e+03. Last save epoch and best loss so far: 8747,  1.973225e+02.
# PDE loss in 8900th epoch:  7.365347e+02. Last save epoch and best loss so far: 8850,  1.961671e+02.
# PDE loss in 9000th epoch:  2.521788e+02. Last save epoch and best loss so far: 8850,  1.961671e+02.
# PDE loss in 9100th epoch:  2.142155e+02. Last save epoch and best loss so far: 9029,  1.914955e+02.
# PDE loss in 9200th epoch:  3.233141e+02. Last save epoch and best loss so far: 9136,  1.868892e+02.
# PDE loss in 9300th epoch:  7.693857e+02. Last save epoch and best loss so far: 9251,  1.847678e+02.
# PDE loss in 9400th epoch:  3.796772e+02. Last save epoch and best loss so far: 9347,  1.832556e+02.
# PDE loss in 9500th epoch:  1.766366e+03. Last save epoch and best loss so far: 9458,  1.785297e+02.
# PDE loss in 9600th epoch:  2.713723e+02. Last save epoch and best loss so far: 9458,  1.785297e+02.
# PDE loss in 9700th epoch:  1.973878e+02. Last save epoch and best loss so far: 9697,  1.747034e+02.
# PDE loss in 9800th epoch:  1.811954e+02. Last save epoch and best loss so far: 9789,  1.712287e+02.
# PDE loss in 9900th epoch:  3.870814e+02. Last save epoch and best loss so far: 9858,  1.694874e+02.
# PDE loss in 10000th epoch:  2.196001e+02. Last save epoch and best loss so far: 9986,  1.683102e+02.
# PDE loss in 10100th epoch:  2.634796e+03. Last save epoch and best loss so far: 9986,  1.683102e+02.
# PDE loss in 10200th epoch:  2.159568e+03. Last save epoch and best loss so far: 10162,  1.661030e+02.
# PDE loss in 10300th epoch:  1.108427e+03. Last save epoch and best loss so far: 10257,  1.614432e+02.
# PDE loss in 10400th epoch:  1.801578e+02. Last save epoch and best loss so far: 10394,  1.607433e+02.
# PDE loss in 10500th epoch:  3.753058e+02. Last save epoch and best loss so far: 10448,  1.553591e+02.
# PDE loss in 10600th epoch:  2.032413e+03. Last save epoch and best loss so far: 10574,  1.536521e+02.
# PDE loss in 10700th epoch:  6.491912e+02. Last save epoch and best loss so far: 10668,  1.524428e+02.
# PDE loss in 10800th epoch:  6.363460e+02. Last save epoch and best loss so far: 10764,  1.509859e+02.
# PDE loss in 10900th epoch:  1.778139e+02. Last save epoch and best loss so far: 10873,  1.480234e+02.
# PDE loss in 11000th epoch:  4.366231e+03. Last save epoch and best loss so far: 10873,  1.480234e+02.
# PDE loss in 11100th epoch:  2.436749e+02. Last save epoch and best loss so far: 10873,  1.480234e+02.
# PDE loss in 11200th epoch:  1.637169e+02. Last save epoch and best loss so far: 11118,  1.445542e+02.
# PDE loss in 11300th epoch:  1.435119e+02. Last save epoch and best loss so far: 11280,  1.415797e+02.
# PDE loss in 11400th epoch:  7.684126e+02. Last save epoch and best loss so far: 11280,  1.415797e+02.
# PDE loss in 11500th epoch:  1.646637e+02. Last save epoch and best loss so far: 11280,  1.415797e+02.
# PDE loss in 11600th epoch:  1.449497e+02. Last save epoch and best loss so far: 11280,  1.415797e+02.
# PDE loss in 11700th epoch:  1.416061e+02. Last save epoch and best loss so far: 11693,  1.349758e+02.
# PDE loss in 11800th epoch:  2.507993e+03. Last save epoch and best loss so far: 11705,  1.348151e+02.
# PDE loss in 11900th epoch:  1.545627e+02. Last save epoch and best loss so far: 11705,  1.348151e+02.
# PDE loss in 12000th epoch:  1.395307e+02. Last save epoch and best loss so far: 11705,  1.348151e+02.
# PDE loss in 12100th epoch:  1.312400e+02. Last save epoch and best loss so far: 12094,  1.293042e+02.
# PDE loss in 12200th epoch:  1.348011e+02. Last save epoch and best loss so far: 12094,  1.293042e+02.
# PDE loss in 12300th epoch:  3.215328e+02. Last save epoch and best loss so far: 12214,  1.268201e+02.
# PDE loss in 12400th epoch:  3.710869e+03. Last save epoch and best loss so far: 12214,  1.268201e+02.
# PDE loss in 12500th epoch:  4.023124e+02. Last save epoch and best loss so far: 12494,  1.250880e+02.
# PDE loss in 12600th epoch:  1.404603e+03. Last save epoch and best loss so far: 12494,  1.250880e+02.
# PDE loss in 12700th epoch:  1.212346e+02. Last save epoch and best loss so far: 12693,  1.203352e+02.
# PDE loss in 12800th epoch:  2.532913e+03. Last save epoch and best loss so far: 12693,  1.203352e+02.
# PDE loss in 12900th epoch:  2.150826e+03. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13000th epoch:  1.998107e+02. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13100th epoch:  1.320316e+02. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13200th epoch:  1.033626e+03. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13300th epoch:  1.624086e+02. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13400th epoch:  1.000114e+03. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13500th epoch:  1.210761e+03. Last save epoch and best loss so far: 12855,  1.182986e+02.
# PDE loss in 13600th epoch:  6.014584e+02. Last save epoch and best loss so far: 13578,  1.147171e+02.
# PDE loss in 13700th epoch:  1.151184e+02. Last save epoch and best loss so far: 13683,  1.091218e+02.
# PDE loss in 13800th epoch:  5.124841e+03. Last save epoch and best loss so far: 13683,  1.091218e+02.
# PDE loss in 13900th epoch:  1.135984e+03. Last save epoch and best loss so far: 13863,  1.078239e+02.
# PDE loss in 14000th epoch:  3.262879e+02. Last save epoch and best loss so far: 13863,  1.078239e+02.
# PDE loss in 14100th epoch:  5.538561e+02. Last save epoch and best loss so far: 13863,  1.078239e+02.
# PDE loss in 14200th epoch:  8.761649e+02. Last save epoch and best loss so far: 14149,  1.062357e+02.
# PDE loss in 14300th epoch:  1.763822e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14400th epoch:  2.720466e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14500th epoch:  2.623193e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14600th epoch:  1.994131e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14700th epoch:  8.700366e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14800th epoch:  3.667552e+02. Last save epoch and best loss so far: 14230,  1.041230e+02.
# PDE loss in 14900th epoch:  1.699740e+02. Last save epoch and best loss so far: 14843,  9.858698e+01.
# PDE loss in 15000th epoch:  1.225033e+02. Last save epoch and best loss so far: 14843,  9.858698e+01.
# PDE loss in 15100th epoch:  4.098196e+03. Last save epoch and best loss so far: 15064,  9.630743e+01.
# PDE loss in 15200th epoch:  9.086433e+02. Last save epoch and best loss so far: 15064,  9.630743e+01.
# PDE loss in 15300th epoch:  3.448409e+03. Last save epoch and best loss so far: 15275,  9.553616e+01.
# PDE loss in 15400th epoch:  1.238886e+03. Last save epoch and best loss so far: 15373,  9.380544e+01.
# PDE loss in 15500th epoch:  1.636436e+03. Last save epoch and best loss so far: 15373,  9.380544e+01.
# PDE loss in 15600th epoch:  2.410830e+03. Last save epoch and best loss so far: 15564,  9.271420e+01.
# PDE loss in 15700th epoch:  2.164110e+02. Last save epoch and best loss so far: 15564,  9.271420e+01.
# PDE loss in 15800th epoch:  2.376315e+02. Last save epoch and best loss so far: 15765,  9.162325e+01.
# PDE loss in 15900th epoch:  3.413796e+03. Last save epoch and best loss so far: 15858,  8.964429e+01.
# PDE loss in 16000th epoch:  2.941819e+02. Last save epoch and best loss so far: 15858,  8.964429e+01.
# PDE loss in 16100th epoch:  4.314093e+02. Last save epoch and best loss so far: 16047,  8.810904e+01.
# PDE loss in 16200th epoch:  4.194743e+02. Last save epoch and best loss so far: 16047,  8.810904e+01.
# PDE loss in 16300th epoch:  5.163452e+02. Last save epoch and best loss so far: 16047,  8.810904e+01.
# PDE loss in 16400th epoch:  1.968005e+03. Last save epoch and best loss so far: 16047,  8.810904e+01.
# PDE loss in 16500th epoch:  1.107589e+02. Last save epoch and best loss so far: 16047,  8.810904e+01.
# PDE loss in 16600th epoch:  1.781460e+02. Last save epoch and best loss so far: 16576,  8.615006e+01.
# PDE loss in 16700th epoch:  4.172223e+02. Last save epoch and best loss so far: 16576,  8.615006e+01.
# PDE loss in 16800th epoch:  1.342372e+03. Last save epoch and best loss so far: 16576,  8.615006e+01.
# PDE loss in 16900th epoch:  4.938405e+02. Last save epoch and best loss so far: 16576,  8.615006e+01.
# PDE loss in 17000th epoch:  6.722597e+02. Last save epoch and best loss so far: 16934,  8.324733e+01.
# PDE loss in 17100th epoch:  5.998873e+02. Last save epoch and best loss so far: 17063,  8.245456e+01.
# PDE loss in 17200th epoch:  1.939947e+02. Last save epoch and best loss so far: 17153,  8.092001e+01.
# PDE loss in 17300th epoch:  1.164421e+03. Last save epoch and best loss so far: 17259,  8.022607e+01.
# PDE loss in 17400th epoch:  8.178865e+01. Last save epoch and best loss so far: 17376,  7.886024e+01.
# PDE loss in 17500th epoch:  7.860738e+01. Last save epoch and best loss so far: 17376,  7.886024e+01.
# PDE loss in 17600th epoch:  1.871856e+02. Last save epoch and best loss so far: 17524,  7.817333e+01.
# PDE loss in 17700th epoch:  1.171819e+03. Last save epoch and best loss so far: 17524,  7.817333e+01.
# PDE loss in 17800th epoch:  7.900066e+01. Last save epoch and best loss so far: 17797,  7.711807e+01.
# PDE loss in 17900th epoch:  1.863353e+03. Last save epoch and best loss so far: 17797,  7.711807e+01.
# PDE loss in 18000th epoch:  5.993200e+02. Last save epoch and best loss so far: 17797,  7.711807e+01.
# PDE loss in 18100th epoch:  2.563277e+02. Last save epoch and best loss so far: 17797,  7.711807e+01.
# PDE loss in 18200th epoch:  7.202952e+02. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18300th epoch:  9.983426e+01. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18400th epoch:  2.140403e+02. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18500th epoch:  9.080064e+01. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18600th epoch:  1.769674e+02. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18700th epoch:  1.097908e+02. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18800th epoch:  4.274075e+02. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 18900th epoch:  1.169020e+03. Last save epoch and best loss so far: 18138,  7.531113e+01.
# PDE loss in 19000th epoch:  6.125359e+02. Last save epoch and best loss so far: 18949,  7.479649e+01.
# PDE loss in 19100th epoch:  2.004148e+02. Last save epoch and best loss so far: 18949,  7.479649e+01.
# PDE loss in 19200th epoch:  2.691017e+02. Last save epoch and best loss so far: 19139,  7.446986e+01.
# PDE loss in 19300th epoch:  2.733216e+02. Last save epoch and best loss so far: 19234,  7.314072e+01.
# PDE loss in 19400th epoch:  1.308244e+02. Last save epoch and best loss so far: 19234,  7.314072e+01.
# PDE loss in 19500th epoch:  3.250761e+02. Last save epoch and best loss so far: 19443,  7.057305e+01.
# PDE loss in 19600th epoch:  1.310282e+02. Last save epoch and best loss so far: 19443,  7.057305e+01.
# PDE loss in 19700th epoch:  2.572501e+03. Last save epoch and best loss so far: 19443,  7.057305e+01.
# PDE loss in 19800th epoch:  1.186034e+03. Last save epoch and best loss so far: 19751,  6.761843e+01.
# PDE loss in 19900th epoch:  8.833758e+01. Last save epoch and best loss so far: 19751,  6.761843e+01.
# Current loss  8.388143e+01, Best loss  6.747453e+01. Restoring best model weights.

# %% [markdown]
# ## Loss vs. number of epochs

# %%
fig = plt.figure(1)
plt.semilogy(range(0, epochs), PDE_loss1)
plt.xlabel('epochs')
plt.ylabel('loss')

plt.grid()
plt.show()

# %% [markdown]
# ## Errors vs. epochs

# %%
fig = plt.figure(2)
plt.semilogy(range(0, epochs), PDE_loss1, range(0, epochs), N_loss1, range(0, epochs), gradient_loss1, range(0, epochs), divergence_loss1)
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['PDE','function','gradient','divergence'])

plt.grid()
plt.show()

# %% [markdown]
# ## Relative $L^2$ error. (Calculate using Monte-Carlo)

# %%
# relative L^2 error
input_data_MC = np.random.uniform(0 ,1, (2*N,input_dim))
z_model = model5(input_data_MC)
z_model = tf.reshape(z_model, [2*N])
z_exact = np.sin(4*np.pi*input_data_MC[:, 0]) * np.sin(2*np.pi*input_data_MC[:, 1])
error = np.sqrt(sum(np.square(z_model - z_exact)))/np.sqrt(sum(np.square(z_exact)))
print(error)
# Out:
# 0.025776502982073433

# %%
plt.plot(z_model-z_exact)

# %% [markdown]
# ## Compare the NN results with the exact solution

# %%
# Define x3,x4,x5,x6 here
M_plot = 50
x3, x4, x5, x6 = 0, 0, -0.03, 0

x = np.outer(np.linspace(0,1,M_plot), np.ones(M_plot))
y = x.copy().T
z_true = np.sin(4*np.pi*x) * np.sin(2*np.pi*y)

x = x.reshape(M_plot**2,1)
y = y.reshape(M_plot**2,1)
x3 = x3* np.ones((M_plot**2,1))
x4 = x4* np.ones((M_plot**2,1))
x5 = x5* np.ones((M_plot**2,1))
x6 = x6* np.ones((M_plot**2,1))
z_model = model5(np.concatenate((x, y, x3, x4, x5, x6), axis=1))
z_model = z_model.numpy().reshape(M_plot,M_plot)

# %%
fig = plt.figure()
ax1 = plt.axes(projection='3d')
x = x.reshape(M_plot,M_plot)
y = y.reshape(M_plot,M_plot)
function_error = z_model - z_true
ax1.plot_wireframe(x,y,function_error)
ax1.view_init(20,45)
ax1.set_title("Error original function")
# Out:
# Text(0.5, 0.92, 'Error original function')
